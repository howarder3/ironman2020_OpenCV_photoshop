# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
from IPython.display import clear_output

# %%
def show_img(img):
    plt.style.use('dark_background')
#     plt.figure(figsize=(10,10)) 
    image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.show()

# %%
def draw_cirlces(img, circle_mid, color, radius):
    cv2.circle(img, circle_mid, radius, color, -1)
    
    return img

# %%
shape = (200, 200, 3)
img1 = np.zeros(shape, np.uint8)
img1 = draw_cirlces(img1, circle_mid=(80,80), color=(255,255,255) ,radius=50)

print("Picture 1 :")
show_img(img1)

shape = (200, 200, 3)
img2 = np.zeros(shape, np.uint8)
img2 = draw_cirlces(img2, circle_mid=(120,120), color=(255,0,0) ,radius=50)


print("Picture 2 :")
show_img(img2)

print("Picture 1 or 2 :")
img1_img2_or =cv2.bitwise_or(img1, img2, dst=None, mask=None)
show_img(img1_img2_or)

print("Picture 1 and 2 :")
img1_img2_and =cv2.bitwise_and(img1, img2, dst=None, mask=None)
show_img(img1_img2_and)

print("Picture 1 xor 2 :")
img1_img2_xor =cv2.bitwise_xor(img1, img2, dst=None, mask=None)
show_img(img1_img2_xor)

print("Picture 1 not :")
img1_not =cv2.bitwise_not(img1)
show_img(img1_not)
# Out:
# Picture 1 :
# Picture 2 :
# Picture 1 or 2 :
# Picture 1 and 2 :
# Picture 1 xor 2 :
# Picture 1 not :

# %%
def img_processing(img):
    # do something here
    
    print("Gray image:")
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # start from BGR -> gray
    show_img(gray)

    print("GaussianBlur image:")
    blur_img = do_GaussianBlur(gray)
    show_img(blur_img)
    
    print("Canny edges:")
    edges = do_Canny(blur_img)
    show_img(edges)
    
#     # ---------------- 印出結果圖表 ---------------- #

    plt.figure(figsize=(15,10)) 
    
    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Origin picture", {'fontsize':20}) 
    
    plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(blur_img, cv2.COLOR_BGR2RGB))
    plt.title("GaussianBlur", {'fontsize':20})  

    
    plt.subplot(1, 3, 3)
    plt.imshow(cv2.cvtColor(edges, cv2.COLOR_BGR2RGB))
    plt.title("Canny", {'fontsize':20})
    
    plt.show()

# %%
def resize_img(img):

    scale_percent = 30 # percent of original size
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    dim = (width, height)  
    resize_img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)  
        
    return resize_img

# %%
cat_img = cv2.imread("./testdata/cat.jpg")
opencv_img = cv2.imread("./testdata/opencv.png")

print("Cat image:")
show_img(cat_img)

print("OpenCV image:")
show_img(opencv_img)


print("OpenCV resize image:")
opencv_img_resize = resize_img(opencv_img) # 縮小成30%
show_img(opencv_img_resize)



# img_processing(origin_img)
# Out:
# Cat image:
# OpenCV image:
# OpenCV resize image:

# %% [markdown]
# # Reference
#
# https://blog.csdn.net/JNingWei/article/details/78241973
#
# https://blog.csdn.net/qq_41895190/article/details/82905657
#
# https://medium.com/%E4%B8%80%E5%80%8B%E4%BA%BA%E7%9A%84%E6%96%87%E8%97%9D%E5%BE%A9%E8%88%88/boolean%E5%9C%96%E5%BD%A2%E6%8E%A7%E5%88%B6%E5%B0%8F%E9%81%8A%E6%88%B2-f5bb22a1e1c2
